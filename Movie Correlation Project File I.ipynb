# %%
# First, we import libraries 

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create

pd.options.mode.chained_assignment = None

# Read in the data

df = pd.read_csv(r'C:\Users\iniad\Downloads\movies.csv')

# %%
# let's look at the data

df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Let's see if there is any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# Data types for our columns

df.dtypes
# Out:
# name            str
# rating          str
# genre           str
# year          int64
# released        str
# score       float64
# votes       float64
# director        str
# writer          str
# star            str
# country         str
# budget      float64
# gross       float64
# company         str
# runtime     float64
# dtype: object

# %%
# Change the data type of columns

df['budget'] = df['budget'].astype('Int64')  

df['gross'] = df['gross'].astype('Int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Create correct year column

df['yearcorrect'] = df['released'].astype(str).str[:4]

# %%
# Order by revenue gross

df = df.sort_values(by=['gross'], inplace = False, ascending = False)

# %%
pd.set_option('display.max_rows', None)

# %%
# Remove duplicates

df.drop_duplicates()
# Out:
#                                                    name     rating      genre  \
# 5445                                             Avatar      PG-13     Action
# 7445                                  Avengers: Endgame      PG-13     Action
# 3045                                            Titanic      PG-13      Drama
# 6663         Star Wars: Episode VII - The Force Awakens      PG-13     Action
# 7244                             Avengers: Infinity War      PG-13     Action
# 7480                                      The Lion King         PG  Animation
# 6653                                     Jurassic World      PG-13     Action
# 6043                                       The Avengers      PG-13     Action
# 6646                                          Furious 7      PG-13     Action
# 7494                                          Frozen II         PG  Animation
# 6644                            Avengers: Age of Ultron      PG-13     Action
# ...

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Budget high correlation
# Company high correlation

# %%
# Scatter plot of budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')

plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'teal'}, line_kws={'color': 'coral'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Let's start looking at correlation

# %%
df.corr(numeric_only=True, method='pearson') #pearson, spearman, kendall
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
df.corr(numeric_only=True, method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.317336  0.293084  0.142977
# score    0.099045  1.000000  0.428138 -0.001403  0.126116  0.399857
# votes    0.469829  0.428138  1.000000  0.502466  0.742050  0.290159
# budget   0.317336 -0.001403  0.502466  1.000000  0.693670  0.336370
# gross    0.293084  0.126116  0.742050  0.693670  1.000000  0.246243
# runtime  0.142977  0.399857  0.290159  0.336370  0.246243  1.000000

# %%
df.corr(numeric_only=True, method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
correlation_matrix = df.corr(numeric_only=True, method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
# Analyzes company

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000  0.303922  0.138277  0.253700  0.654899  0.106870
# rating       0.303922  1.000000 -0.012156  0.037943  0.237101 -0.065634
# genre        0.138277 -0.012156  1.000000  0.087977  0.091299  0.063222
# year         0.253700  0.037943  0.087977  1.000000  0.315878  0.076737
# released     0.654899  0.237101  0.091299  0.315878  1.000000  0.069151
# score        0.106870 -0.065634  0.063222  0.076737  0.069151  1.000000
# votes        0.595689  0.118085  0.148277  0.326421  0.449957  0.233450
# director     0.720202  0.235022  0.093275  0.173060  0.502859  0.149505
# writer       0.782882  0.255885  0.088035  0.212142  0.547903  0.103719
# star         0.652838  0.243614  0.097916  0.227367  0.476306  0.106059
# country      0.190609  0.158866 -0.073886 -0.053610  0.162029 -0.098456
# budget       0.026200  0.052863  0.083745  0.030935  0.016702 -0.000201
# ...

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name         name           1.000000
#              rating         0.303922
#              genre          0.138277
#              year           0.253700
#              released       0.654899
#              score          0.106870
#              votes          0.595689
#              director       0.720202
#              writer         0.782882
#              star           0.652838
#              country        0.190609
#              budget         0.026200
#              gross          0.843755
#              company        0.682841
#              runtime        0.071805
#              yearcorrect    0.108828
# rating       name           0.303922
#              rating         1.000000
#              genre         -0.012156
#              year           0.037943
#              released       0.237101
#              score         -0.065634
#              votes          0.118085
#              director       0.235022
#              writer         0.255885
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

print(sorted_pairs)
# Out:
# score        country       -0.098456
# country      score         -0.098456
#              budget        -0.091056
# budget       country       -0.091056
# country      genre         -0.073886
# genre        country       -0.073886
# score        rating        -0.065634
# rating       score         -0.065634
# year         country       -0.053610
# country      year          -0.053610
# budget       director      -0.031082
# director     budget        -0.031082
# votes        budget        -0.020308
# budget       votes         -0.020308
# yearcorrect  genre         -0.017806
# genre        yearcorrect   -0.017806
#              rating        -0.012156
# rating       genre         -0.012156
# writer       budget        -0.010439
# budget       writer        -0.010439
#              company       -0.006830
# company      budget        -0.006830
# star         budget        -0.006390
# budget       star          -0.006390
# runtime      yearcorrect   -0.005799
# ...

# %%
# Analysis of the highest correlation (> 0.5)

# %%
high_corr = sorted_pairs[abs(sorted_pairs) > 0.5]

print(high_corr)
# Out:
# released     director       0.502859
# director     released       0.502859
# gross        votes          0.504208
# votes        gross          0.504208
# star         gross          0.516134
# gross        star           0.516134
# votes        writer         0.521099
# writer       votes          0.521099
#              released       0.547903
# released     writer         0.547903
# company      gross          0.548719
# gross        company        0.548719
# released     gross          0.561106
# gross        released       0.561106
# star         company        0.569651
# company      star           0.569651
# star         director       0.580144
# director     star           0.580144
# star         writer         0.589925
# writer       star           0.589925
# name         votes          0.595689
# votes        name           0.595689
# director     gross          0.596073
# gross        director       0.596073
# company      director       0.614240
# ...
